# %%
#Euler project - nr 8

#The four adjacent digits in the 1000-digit number that have the greatest product are 9 × 9 × 8 × 9 = 5832.

# ...

#Find the thirteen adjacent digits in the 1000-digit number that have the greatest product. What is the value of this product?

# %%
#Method 1


x = '...'

list1 = []

results = []

for a in x:
    b = int(a)
    list1.append(b)
    

for n in range (0,986):
    c = list1[n]*list1[n+1]*list1[n+2]*list1[n+3]*list1[n+4]*list1[n+5]*list1[n+6]*list1[n+7]*list1[n+8]*list1[n+9]*list1[n+10]*list1[n+11]*list1[n+12]
    results.append(c)

    
print (max(results))
# Out:
# 23514624000

# %%
#RIGHT ANSWER: 23514624000

# %%
#METHOD 2

# %%
x = '...'

list1 = []

biggest_number = 0

for a in x:
    b = int(a)
    list1.append(b)
    

for n in range (0,986):
    result = 1
    for i in range (n,n+13):
        result *= list1[i]

    if result > biggest_number:
        biggest_number = result


    
print (biggest_number)
# Out:
# 23514624000
